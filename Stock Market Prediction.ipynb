# %%
import yfinance as yf
#calls the yahoo finance api to fetch the data

# %%
sp500=yf.Ticker('^GSPC')

# %%
sp500 = sp500.history(period = "max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-06-05 00:00:00-04:00  4282.990234  4299.279785  4266.819824  4273.790039
# 2023-06-06 00:00:00-04:00  4271.339844  4288.330078  4263.089844  4283.850098
# 2023-06-07 00:00:00-04:00  4285.470215  4299.189941  4263.959961  4267.520020
# 2023-06-08 00:00:00-04:00  4268.689941  4298.009766  4261.069824  4293.930176
# 2023-06-09 00:00:00-04:00  4304.879883  4322.620117  4291.700195  4298.859863
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2023-05-26 00:00:00-04:00', '2023-05-30 00:00:00-04:00',
#                '2023-05-31 00:00:00-04:00', '2023-06-01 00:00:00-04:00',
#                '2023-06-02 00:00:00-04:00', '2023-06-05 00:00:00-04:00',
#                '2023-06-06 00:00:00-04:00', '2023-06-07 00:00:00-04:00',
#                '2023-06-08 00:00:00-04:00', '2023-06-09 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=23975, freq=None)

# %% [markdown]
# # Cleaning and Visualising Stock Market Data

# %%
sp500.plot.line(y = 'Close',use_index = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
del sp500['Dividends']
del sp500['Stock Splits']

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23975 entries, 1927-12-30 00:00:00-05:00 to 2023-06-09 00:00:00-04:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    23975 non-null  float64
#  1   High    23975 non-null  float64
#  2   Low     23975 non-null  float64
#  3   Close   23975 non-null  float64
#  4   Volume  23975 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# # Setting Our target for Machine Learning

# %%
sp500['Tomorrow'] = sp500['Close'].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-06-05 00:00:00-04:00  4282.990234  4299.279785  4266.819824  4273.790039
# 2023-06-06 00:00:00-04:00  4271.339844  4288.330078  4263.089844  4283.850098
# 2023-06-07 00:00:00-04:00  4285.470215  4299.189941  4263.959961  4267.520020
# 2023-06-08 00:00:00-04:00  4268.689941  4298.009766  4261.069824  4293.930176
# 2023-06-09 00:00:00-04:00  4304.879883  4322.620117  4291.700195  4298.859863
#
# ...

# %%
sp500['Target'] = (sp500['Tomorrow']>sp500['Close']).astype('i')

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-06-05 00:00:00-04:00  4282.990234  4299.279785  4266.819824  4273.790039
# 2023-06-06 00:00:00-04:00  4271.339844  4288.330078  4263.089844  4283.850098
# 2023-06-07 00:00:00-04:00  4285.470215  4299.189941  4263.959961  4267.520020
# 2023-06-08 00:00:00-04:00  4268.689941  4298.009766  4261.069824  4293.930176
# 2023-06-09 00:00:00-04:00  4304.879883  4322.620117  4291.700195  4298.859863
#
# ...

# %%
sp500 = sp500.loc['1990-01-01':].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2023-06-05 00:00:00-04:00  4282.990234  4299.279785  4266.819824  4273.790039
# 2023-06-06 00:00:00-04:00  4271.339844  4288.330078  4263.089844  4283.850098
# 2023-06-07 00:00:00-04:00  4285.470215  4299.189941  4263.959961  4267.520020
# 2023-06-08 00:00:00-04:00  4268.689941  4298.009766  4261.069824  4293.930176
# 2023-06-09 00:00:00-04:00  4304.879883  4322.620117  4291.700195  4298.859863
#
# ...

# %% [markdown]
# # Training An Initial ML Model

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

model =RFC(n_estimators = 100,min_samples_split =100,random_state =69)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ['Close','Volume','Open','High','Low']

model.fit(train[predictors],train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=69)

# %%
from sklearn.metrics import precision_score

pred = model.predict(test[predictors])

# %%
import pandas as pd

pred = pd.Series(pred,index = test.index)

# %%
precision_score(test['Target'],pred)
# Out:
# 0.5517241379310345

# %%
combined = pd.concat([test['Target'],pred],axis =1)

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Building A Backtesting System

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train['Target'])
    preds =  model.predict(test[predictors])
    preds = pd.Series(preds,index = test.index, name ='Predictions')
    combined = pd.concat([test['Target'],pred],axis =1)
    
    return combined

# %%
def backtest(data,model,predictors,start = 2500,step = 250):
    all_predictions = []
    
    for i in range(start,data.shape[0],step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        
        predictions = predict(train,test,predictors,model)
        
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)
    print(all_predictions)

# %%
predictions = backtest(sp500, model , predictors)

# %%
predictions
# Out:
#                            Target    0
# Date
# 1999-11-22 00:00:00-05:00     0.0  NaN
# 1999-11-23 00:00:00-05:00     1.0  NaN
# 1999-11-24 00:00:00-05:00     0.0  NaN
# 1999-11-26 00:00:00-05:00     0.0  NaN
# 1999-11-29 00:00:00-05:00     0.0  NaN
# ...                           ...  ...
# 2023-06-05 00:00:00-04:00     1.0  1.0
# 2023-06-06 00:00:00-04:00     0.0  1.0
# 2023-06-07 00:00:00-04:00     1.0  1.0
# 2023-06-08 00:00:00-04:00     1.0  1.0
# 2023-06-09 00:00:00-04:00     0.0  1.0
#
# [8225 rows x 2 columns]

# %%
predictions[0].value_counts()
# Out:
# 0.0    71
# 1.0    29
# Name: 0, dtype: int64

# %%
predictions.dropna(inplace = True)

# %%
precision_score(predictions['Target'],predictions[0])
# Out:
# 0.5517241379310345
