# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir(r"Z:\DataScience_assets\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data")]

data = pd.DataFrame()

for file in files:
    data1 = pd.read_csv(r"Z:\DataScience_assets\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\\" + file)
    data = pd.concat([data,data1])

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #   Data Cleaning

# %%
#drop NaN values
data.dropna(inplace= True)
data.tail(100)
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 11585   259266    USB-C Charging Cable                1      11.95
# 11586   259267  AAA Batteries (4-pack)                1       2.99
# 11587   259268  AAA Batteries (4-pack)                1       2.99
# 11588   259269        27in FHD Monitor                1     149.99
# 11589   259270            Google Phone                1        600
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 11585  09/13/19 05:36        9 2nd St, New York City, NY 10001
# ...

# %%
data.to_csv("Sales_Data.csv",index = False)

# %%
data["Month"] = data['Order Date'].str[0:2]
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
temp = data[data["Month"]=="Or"]  #Checking rows on the basis of error 'Or'
temp
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 10000  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10387  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11399  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11468  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11574  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 519    Purchase Address    Or
# 1149   Purchase Address    Or
# 1155   Purchase Address    Or
# 2878   Purchase Address    Or
# ...

# %%
data = data[data["Month"]!="Or"]
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 11685
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: object(7)
# memory usage: 11.3+ MB

# %%
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
data['Price Each'] = pd.to_numeric(data['Price Each'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 11685
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 11.3+ MB

# %%
data["Sales"] = data["Quantity Ordered"] * data["Price Each"]

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99

# %% [markdown]
# # Q1. Best Month for Sales(in terms of earning)

# %%
sales = data.groupby("Month").sum()  #accumulating sales of all 12 months

# %%
import matplotlib.pyplot as plt

months = range(1,13)

figure = plt.figure(figsize=(5,5))

plt.bar(months,sales['Sales'])
plt.xticks(months)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month")
plt.show()

# %% [markdown]
# # Q2. Which City made the most number of sales??

# %%
data["City"] = data['Purchase Address'].apply(lambda x: x.split(",")[1])

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
city = data.groupby("City").sum()

# %%
city
# Out:
#                 Quantity Ordered  Price Each       Sales
# City
#  Atlanta                   16602  2779908.20  2795498.58
#  Austin                    11153  1809873.61  1819581.75
#  Boston                    22528  3637409.77  3661642.01
#  Dallas                    16730  2752627.82  2767975.40
#  Los Angeles               33289  5421435.23  5452570.80
#  New York City             27932  4635370.83  4664317.43
#  Portland                  14053  2307747.47  2320490.61
#  San Francisco             50239  8211461.74  8262203.91
#  Seattle                   16553  2733296.01  2747755.48

# %%
cities = [city for city,df in data.groupby("City")]
figure = plt.figure(figsize=(5,5))

plt.bar(cities,city['Sales'])
plt.xticks(cities,rotation =90)
plt.ylabel("Sales in USD ($)")
plt.xlabel("City")
plt.show()

# %% [markdown]
# # Q3. What time should we show advertisement to maximize likelihood customer buying the product?

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])

# %%
data['Hour'] = data["Order Date"].dt.hour

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City  Hour
# 0        Dallas     8
# 2        Boston    22
# 3   Los Angeles    14
# ...

# %%
data['Min'] = data["Order Date"].dt.minute

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City  Hour  Min
# 0        Dallas     8   46
# 2        Boston    22   30
# ...

# %%
hours = [hour for hour,df in data.groupby(['Hour']) ]

figure = plt.figure(figsize=(10,5))

plt.plot(hours,data.groupby(['Hour']).count())
plt.xticks(hours)
plt.ylabel("No. of Orders")
plt.xlabel("Time")
plt.grid()
plt.show()

# %% [markdown]
# # Q4 Most selling product

# %%
def category(x):
    if x.split()[-1] != "(4-pack)":
        return x.split()[-1]
    else:
        return x.split()[-2]

# %%
data["Product Category"] = data['Product'].apply(lambda x:category(x))

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City  Hour  Min Product Category
# 0        Dallas     8   46            Cable
# ...

# %%
pro_cat = data.groupby("Product Category").sum()

# %%
data[data.Product.str.contains("(4-pack)")]
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_16764\3936848707.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   data[data.Product.str.contains("(4-pack)")]
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 14      176570   AA Batteries (4-pack)                 1        3.84
# 20      176575  AAA Batteries (4-pack)                 1        2.99
# 24      176579   AA Batteries (4-pack)                 1        3.84
# 28      176583  AAA Batteries (4-pack)                 2        2.99
# 32      176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...                     ...               ...         ...
# 11669   259342   AA Batteries (4-pack)                 1        3.84
# 11671   259344  AAA Batteries (4-pack)                 2        2.99
# 11674   259347   AA Batteries (4-pack)                 1        3.84
# ...

# %%
pro_cat1 = [pro_cat for pro_cat,df in data.groupby("Product Category")  ]

figure = plt.figure(figsize=(5,5))

plt.bar(pro_cat1,pro_cat['Sales'])
plt.xticks(pro_cat1, rotation = 90)
plt.ylabel("No. of Orders")
plt.xlabel("Product Category")
plt.show()

# %%
prices
# Out:
# Product Category
# Batteries        3.414340
# Cable           13.441564
# Dryer          600.000000
# Headphones      81.479017
# Laptop        1373.560633
# Machine        600.000000
# Monitor        264.598851
# Phone          545.586298
# TV             300.000000
# iPhone         700.000000
# Name: Price Each, dtype: float64

# %% [markdown]
# # Q5. Which are the two most sold together product

# %%
data[data["Sales"]==max(data["Sales"])]
# Out:
#      Order ID             Product  Quantity Ordered  Price Each  \
# 4717   181069  Macbook Pro Laptop                 2      1700.0
# 5219   181544  Macbook Pro Laptop                 2      1700.0
# 385    210292  Macbook Pro Laptop                 2      1700.0
# 6776   200528  Macbook Pro Laptop                 2      1700.0
#
#               Order Date                       Purchase Address Month   Sales  \
# 4717 2019-04-27 21:01:00   668 Park St, San Francisco, CA 94016    04  3400.0
# 5219 2019-04-22 12:48:00   731 11th St, New York City, NY 10001    04  3400.0
# 385  2019-06-08 09:00:00  953 Ridge St, San Francisco, CA 94016    06  3400.0
# 6776 2019-05-13 13:40:00           643 4th St, Boston, MA 02215    05  3400.0
#
#                 City  Hour  Min Product Category
# 4717   San Francisco    21    1           Laptop
# 5219   New York City    12   48           Laptop
# 385    San Francisco     9    0           Laptop
# 6776          Boston    13   40           Laptop

# %%
df = data[data["Order ID"].duplicated(keep = False)]
df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
# 129   176681    Apple Airpods Headphones                 1      150.00
# 130   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
df['Grouped'] = df.groupby("Order ID")["Product"].transform(lambda x:",".join(x))
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_16764\3522765552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby("Order ID")["Product"].transform(lambda x:",".join(x))

# %%
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address Month   Sales  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04  600.00
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04   11.95
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215    04   99.99
#
#             City  Hour  Min Product Category  \
# ...

# %%
df = df[['Order ID','Grouped']].drop_duplicates()

# %%
df
# Out:
#       Order ID                                            Grouped
# 3       176560                      Google Phone,Wired Headphones
# 18      176574                  Google Phone,USB-C Charging Cable
# 30      176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32      176586                AAA Batteries (4-pack),Google Phone
# 119     176672      Lightning Charging Cable,USB-C Charging Cable
# ...        ...                                                ...
# 11617   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 11619   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 11627   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 11639   259314            Wired Headphones,AAA Batteries (4-pack)
# 11677   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
df.nunique()
# Out:
# Order ID    7136
# Grouped      366
# dtype: int64

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
    
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
prices = data.groupby("Product Category").mean()['Price Each']

fig,ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(pro_cat1,pro_cat['Quantity Ordered'],color ='b')
ax2.plot(pro_cat1,prices,'r')

ax1.set_xlabel("Product Name")
ax1.set_ylabel("Quantity Ordered", color ='g')
ax2.set_ylabel('Price ($)', color ='b')
ax1.set_xticklabels(pro_cat1,rotation=90,size = 8)
plt.show()
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_16764\2129414090.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(pro_cat1,rotation=90,size = 8)
