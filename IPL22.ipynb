# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset to the script
data = pd.read_csv(r"Z:\DataScience_assets\Datasets\IPL22.csv")

# %%
data.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
data.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
data.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
#check no. of unique values
data.nunique()
# Out:
# match_id               74
# date                   62
# venue                   6
# team1                   9
# team2                   9
# stage                   3
# toss_winner            10
# toss_decision           2
# first_ings_score       55
# first_ings_wkts        10
# second_ings_score      50
# second_ings_wkts       10
# match_winner           10
# won_by                  2
# margin                 31
# player_of_the_match    56
# top_scorer             37
# highscore              46
# best_bowling           42
# best_bowling_figure    51
# dtype: int64

# %%
data.venue.unique()
# Out:
# array(['Wankhede Stadium, Mumbai', 'Brabourne Stadium, Mumbai',
#        'Dr DY Patil Sports Academy, Mumbai',
#        'Maharashtra Cricket Association Stadium,Pune',
#        'Eden Gardens, Kolkata', 'Narendra Modi Stadium, Ahmedabad'],
#       dtype=object)

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data=data, y=data['venue'])
plt.xticks(rotation = 0)
plt.show()

# %%
#matches won by who won the toss

data[data.toss_winner == data.match_winner].value_counts().sum()
# Out:
# 36

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data = data, x=data.toss_winner)
plt.xticks(rotation=90)
plt.show()

# %%
data[(data.toss_winner == data.match_winner) & (data.toss_decision == "Bat")]
# Out:
#     match_id           date                                         venue  \
# 34        35  April 23,2022            Dr DY Patil Sports Academy, Mumbai
# 44        45     May 1,2022                      Wankhede Stadium, Mumbai
# 53        54     May 8,2022                      Wankhede Stadium, Mumbai
# 56        57    May 10,2022  Maharashtra Cricket Association Stadium,Pune
# 60        61    May 14,2022  Maharashtra Cricket Association Stadium,Pune
# 62        63    May 15,2022                     Brabourne Stadium, Mumbai
# 65        66    May 18,2022            Dr DY Patil Sports Academy, Mumbai
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 34    Gujarat    Kolkata  Group     Gujarat           Bat               156
# 44      Delhi    Lucknow  Group     Lucknow           Bat               195
# 53   Banglore  Hyderabad  Group    Banglore           Bat               192
# ...

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data = data , x=data.toss_decision)
plt.xticks(rotation = 0)
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data = data, x = data.player_of_the_match)
plt.xticks(rotation = 90)
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data = data , x=data.won_by)
plt.xticks(rotation = 0)
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.barplot(data = data , 
              x=data.top_scorer,
              y=data.highscore)
plt.xticks(rotation = 90)
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data = data , x=data.best_bowling)
plt.xticks(rotation = 90)
plt.show()
